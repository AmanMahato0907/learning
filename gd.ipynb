# %% [markdown]
# You are given a small dataset where X represents the number of hours practiced and y represents whether a student passed (1) or failed (0).
# [2, 3, 5, 6, 8]
# 0, 0, 1, 1, 1
# Write the gradient descent loop to train the logistic regression model.
#
# Inside the loop:
#
# Compute z = w * X + b
#
# Apply the sigmoid function to get predictions
#
# Calculate:
#
# dw (gradient of weight)
#
# db (gradient of bias)
#
# Update w and b using the learning rate.
#
# Print the final value of weight and bias after training.

# %%
import numpy as pd

# %% [markdown]
# You are given the following dataset and a linear regression model.
# import numpy as np
#
# X = np.array([[1, 1],
#               [1, 2],
#               [1, 3],
#               [1, 4]])
#
# y = np.array([3, 5, 7, 9])
#
# theta = np.array([1, 2])
# Write the formula of the cost function used in linear regression.
#
# Using the given X, y, and theta, calculate the predicted values.
#
# Calculate the cost (Mean Squared Error) manually for this model.
#
# Write a Python function to compute the cost.
#
# What happens to the cost if predictions become more accurate?
